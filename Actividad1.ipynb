# %% [markdown]
# # TEXTO

# %% [markdown]
# ## Funciones Trigonométricas
# ### Coseno= Cos$\theta$
# ### Seno= Sin$\theta$
# ### Tangente= Tan$\theta$
#
#
# <img src='https://www.disfrutalasmatematicas.com/algebra/images/sin-cos-tan.svg' align="center">
#
# <h1>Algunos Valores</h1>
# Los valores que toman estan funciones para los ángulos <br>
#     <ul>
#         <li> $2 \pi$ : 0°</li>
#         <li> $\frac{\pi}{6}$ : 30°</li>
#         <li> $\frac{\pi}{4}$ : 45°</li>
#         <li> $\frac{\pi}{3}$ : 60° </li>
#         <li> $\frac{\pi}{2}$ : 90° </li>
#     </ul>
#     pueden verse en la siguiente imagen
# <a href="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQBxhXcMX5LkeE2xz2BryoEZsklVdvxOw1wmg&usqp=CAU"> Valores para los ángulos</a> <br>
#
#
# ## Grafica de las funciones trigonometricas
#
# <a href="https://www.youtube.com/watch?v=htxnqk8yubg"> Video de Youtube</a> <br>
# <video controls src="https://www.youtube.com/watch?v=htxnqk8yubg" width="500" height="340">

# %% [markdown]
# # IMPORTACIÓN DE LIBRERIAS

# %%
#Importación de Librerias
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # GRAFICAS EN PYTHON

# %%
x=[0,np.pi/6,np.pi/4,np.pi/3,np.pi/2]
plt.scatter(x, np.sin(x))
plt.scatter(x, np.cos(x))
plt.xlabel(r'$\theta$', fontsize=16)
plt.legend(['Sen','Cos'])

# %%
t = np.arange(0.0, 100.0, 0.1)
s = np.sin(0.1 * np.pi * t) * np.exp(-t * 0.01)
fig, ax = plt.subplots()
ax.plot(t, s)
